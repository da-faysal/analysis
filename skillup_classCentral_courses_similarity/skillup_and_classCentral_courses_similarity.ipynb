# %% [markdown]
# ### Purpose: To find similar courses between classcentral and skillup by matching keywords of skillup with the courses title of classcentral, so that we can publish popular courses on classcentral from skillup to generate leads.

# %%
# Import modules
import pandas as pd
import numpy as np

# %%
# Read in class central data
class_central_df = pd.read_excel("classCentral_26Aug.xlsx")
class_central_df.head()
# Out:
#                                          courseTitle  \
# 0                                     Elements of AI
# 1                                   Machine Learning
# 2             Unlocking Information Security: Part Ⅰ
# 3  Introduction to Computer Science and Programmi...
# 4            CS50's Introduction to Computer Science
#
#                                           courseLink  \
# 0  https://www.classcentral.com/course/independen...
# 1  https://www.classcentral.com/course/machine-le...
# 2  https://www.classcentral.com/course/edx-unlock...
# 3  https://www.classcentral.com/course/edx-introd...
# 4  https://www.classcentral.com/course/edx-cs50-s...
#
#                                       courseProvider  \
# 0  University of Helsinki and Reaktor Education v...
# 1                   Stanford University via Coursera
# 2                        Tel Aviv University via edX
# 3      Massachusetts Institute of Technology via edX
# 4                         Harvard University via edX
#
#                                                  cat unitSold  \
# 0  Computer Science\n\n\n\n\nArtificial Intelligence    31.2k
# 1         Computer Science\n\n\n\n\nMachine Learning    62.3k
# 2            Computer Science\n\n\n\n\nCybersecurity     3.5k
# 3                                   Computer Science    16.4k
# 4                                   Computer Science    26.6k
#
#                  certificatePrice                 freeOrAudit       review
# 0           Certificate Available          Free Online Course  574 reviews
# 1      Paid Certificate Available  Free Online Course (Audit)  369 reviews
# 2  5 weeks long, 4-6 hours a week  Free Online Course (Audit)  151 reviews
# 3       $75 Certificate Available  Free Online Course (Audit)  126 reviews
# 4       $90 Certificate Available  Free Online Course (Audit)   96 reviews

# %% [markdown]
# #### Processing, cleaning, and feature engineering:

# %%
# Extract subcategory and broadcategory from cat columns
class_central_df["subCat"] = class_central_df.cat.str.split("\n").str[-1]
class_central_df["broadCat"] = class_central_df.cat.str.split("\n").str[0]

# Extract digits from review
class_central_df["review"] = class_central_df.review.str.extract(r"(\d+,?)")


# Multiply by 1000 where unit sale contains "k", otherwise keep that as it is.
class_central_df["unitSold"] = np.where(class_central_df.unitSold.str.contains("k", na=False), 
        class_central_df.unitSold.str.replace("k", "").fillna(0).astype(float).multiply(1000).astype(int),
        class_central_df.unitSold).astype(int)

# Extract colaborating university from course provider column
class_central_df["colaboratingUniv"] = class_central_df.courseProvider.str.split("via").str[0].str.strip()


# Extract only course provider without colaborating university
class_central_df.courseProvider = class_central_df.courseProvider.str.split("via").str[-1].str.strip()

# Is the course is free, paid or auditable?
class_central_df["freeAuditOrPaid"] = np.where(class_central_df.freeOrAudit.str.contains("Audit"), "audit",
        np.where(class_central_df.freeOrAudit.str.contains("Free"), "free",
                np.where(class_central_df.freeOrAudit.str.contains("Paid"), "paid", class_central_df.freeOrAudit)))

# Is certificate free, paid or have some price?
class_central_df["certificatePrice"] = np.where(class_central_df.certificatePrice.str.contains("Paid"), "paid",
       np.where(class_central_df.certificatePrice.str.contains("\$"), class_central_df.certificatePrice,
                 np.where(class_central_df.certificatePrice.str.contains("Certificate Available"), "free", "na")))

# Split by certificate price, otherwise keep it as it is.
class_central_df["certificatePrice"] = np.where(class_central_df.certificatePrice.str.contains("\$"), 
         class_central_df.certificatePrice.str.split("Certificate Available").str[0], class_central_df.certificatePrice)

# Drop category column
class_central_df.drop("cat", axis=1, inplace=True)

# Sort by unit sale
class_central_df = class_central_df.sort_values("unitSold", ascending=False)

# %%
# Read in skillup data
skillup_df = pd.read_excel("skillUp.xlsx")
skillup_df.head()
# Out:
#      date  courseId                                        courseTitle  \
# 0  18_Aug    277314   Animal Care and Pet First Aid - 5 Courses Bundle
# 1  18_Aug    273817           Dog Trainer - 8 Courses Complete Bundle
# 2  18_Aug    273884   Photography Bundle for Professional Photographer
# 3  18_Aug    277102                    BARF - Feed Your Dog A Raw Diet
# 4  18_Aug    277218  Reiki Diploma - Level 1 to Master Level Certif...
#
#                                              keyword  \
# 0                                        animal care
# 1  dog trainer|dog training|dog|dog walking|raw d...
# 2                    photography|wedding photography
# 3  dog trainer|dog training|dog|dog walking|raw d...
# 4                                              reiki
#
#                                             subTitle  \
# 0  Special Bundle Offer | Accredited by CPD | 13 ...
# 1  Special Bundle Offer | Accredited by CPD | 40 ...
# 2  Special Bundle Offer | Accredited by CPD | 45 ...
# 3  Accredited by CPD | 3 CPD Points | Video train...
# 4  Accredited by CPD | 4 CPD Points | Video train...
#
#                                           courseLink courseProvider  \
# 0  https://www.reed.co.uk/courses/animal-care-and...       Skill Up
# 1  https://www.reed.co.uk/courses/dog-trainer-8-c...       Skill Up
# 2  https://www.reed.co.uk/courses/photography-bun...       Skill Up
# 3  https://www.reed.co.uk/courses/barf-feed-your-...       Skill Up
# 4  https://www.reed.co.uk/courses/reiki-diploma-l...       Skill Up
#
#                            soldOrEnq  \
# 0   3 students purchased this course
# 1  11 students purchased this course
# 2   5 students purchased this course
# 3   5 students purchased this course
# 4  10 students purchased this course
#
#                                             category broadCategory1  ...  \
# 0     Animal care, Veterinary, Animal care, Dog care    Animal care  ...
# 1  Animal care, Dog training, Animal care, Dog tr...    Animal care  ...
# 2  Media and art, Photography, Recreational, Phot...  Media and art  ...
# 3  Animal care, Dog agility, Animal care, Dog wal...    Animal care  ...
# 4         Health & care, Alternative medicine, Reiki  Health & care  ...
#
#   cpdAccreditedBy othersAsCpd awrBodyName  awrBodyQualName courseLevel  \
# 0             NaN         NaN         NaN              NaN         NaN
# 1             NaN         NaN         NaN              NaN         NaN
# 2             NaN         NaN         NaN              NaN         NaN
# 3             NaN         NaN         NaN              NaN         NaN
# 4             NaN         NaN         NaN              NaN         NaN
#
#   savings newOfferPrice unitSold offerPrice  savingsPercent
# 0     NaN           NaN        3         39              96
# 1     NaN           NaN       11         49              94
# 2     NaN           NaN        5         49              94
# 3     NaN           NaN        5         10              95
# 4     NaN           NaN       10         10              95
#
# [5 rows x 29 columns]

# %%
# This function match keywords of skillup courses with the title of class central courses
def matchByKeyword(keyword):
    """Keyword: keyword in the skill up dataset."""
    
    # Search classcentral course title
    in_course_cenreal = class_central_df[class_central_df["courseTitle"].str.contains(fr"\b({keyword})\b", case=False, regex=True)]
    
    # Insert keyword
    in_course_cenreal.insert(loc=0, value=keyword, column="keyword")
    
    # Match keyword with the skill up keyword column
    match_with_skillup = skillup_df[skillup_df.keyword==keyword]
    
    # Concat if a keyword is found on both of the dataframes
    if in_course_cenreal.shape[0]>0 and match_with_skillup.shape[0]>0:
        return pd.concat([match_with_skillup, in_course_cenreal.head(10)])

# %%
# Call the function on array of keywords
matched = pd.concat(list(map(matchByKeyword, skillup_df.keyword.unique()))).reset_index(drop=True)

# Sort by keywords
matched = matched.sort_values(["keyword"])
matched.head(10)
# Out:
# /home/faysal/anaconda3/lib/python3.8/site-packages/pandas/core/strings/accessor.py:101: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#        date  courseId                                        courseTitle  \
# 390  18_Aug  277471.0                     Acrylic Painting for Beginners
# 392     NaN       NaN                    The Art of Drawing and Painting
# 393     NaN       NaN           In the Studio: Postwar Abstract Painting
# 394     NaN       NaN                         Secondary : Painting (225)
# 395     NaN       NaN                      Sr.Secondary : Painting (332)
# 391  18_Aug  277480.0                     Modern Acrylic Painting Course
# 385  18_Aug  277470.0                      Adobe Illustrator CC Beginner
# 386  18_Aug  278250.0                 Complete Adobe Illustrator CC 2018
# 387  18_Aug  278308.0                      Adobe Illustrator CC Advanced
# 388     NaN       NaN  Adobe Illustrator: aprende a crear presentacio...
#
#                        keyword  \
# 390  Acrylic Painting|painting
# 392  Acrylic Painting|painting
# 393  Acrylic Painting|painting
# 394  Acrylic Painting|painting
# 395  Acrylic Painting|painting
# 391  Acrylic Painting|painting
# 385          Adobe Illustrator
# 386          Adobe Illustrator
# 387          Adobe Illustrator
# 388          Adobe Illustrator
#
#                                               subTitle  \
# 390  Accredited by CPD | 4 CPD Points | Video train...
# 392                                                NaN
# 393                                                NaN
# 394                                                NaN
# 395                                                NaN
# 391  Accredited by CPD | 3 CPD Points | Video train...
# 385  Accredited by CPD | 4 CPD Points | Video train...
# 386  Accredited by CPD | 12 CPD Points | Video trai...
# 387  Accredited by CPD | 2 CPD Points | Video train...
# 388                                                NaN
#
#                                             courseLink courseProvider  \
# 390  https://www.reed.co.uk/courses/acrylic-paintin...       Skill Up
# 392  https://www.classcentral.com/course/open2study...     Open2Study
# 393  https://www.classcentral.com/course/painting-8349       Coursera
# 394  https://www.classcentral.com/course/swayam-sec...         Swayam
# 395  https://www.classcentral.com/course/swayam-sr-...         Swayam
# 391  https://www.reed.co.uk/courses/modern-acrylic-...       Skill Up
# 385  https://www.reed.co.uk/courses/adobe-illustrat...       Skill Up
# 386  https://www.reed.co.uk/courses/complete-adobe-...       Skill Up
# 387  https://www.reed.co.uk/courses/adobe-illustrat...       Skill Up
# 388  https://www.classcentral.com/course/edx-adobe-...            edX
#
#                           soldOrEnq  \
# 390  Tutor is available to students
# 392                             NaN
# 393                             NaN
# 394                             NaN
# 395                             NaN
# 391  Tutor is available to students
# 385  Tutor is available to students
# 386  Tutor is available to students
# 387  Tutor is available to students
# 388                             NaN
#
#                                               category broadCategory1  ...  \
# 390  Construction, Painting and Decorating, Media a...   Construction  ...
# 392                                                NaN            NaN  ...
# 393                                                NaN            NaN  ...
# 394                                                NaN            NaN  ...
# 395                                                NaN            NaN  ...
# 391  Construction, Painting and Decorating, Media a...   Construction  ...
# 385                Design, Media and art, Illustration         Design  ...
# 386  Media and art, Photography, Recreational, Phot...  Media and art  ...
# 387  Media and art, Photography, Recreational, Phot...  Media and art  ...
# 388                                                NaN            NaN  ...
#
#     unitSold offerPrice savingsPercent  certificatePrice  \
# 390        0       10.0           95.0               NaN
# 392     2000        NaN            NaN                na
# 393      715        NaN            NaN              paid
# 394       76        NaN            NaN              paid
# 395       67        NaN            NaN              paid
# 391        0       10.0           95.0               NaN
# 385        0       10.0           95.0               NaN
# 386        0       10.0           95.0               NaN
# 387        0       10.0           95.0               NaN
# 388      165        NaN            NaN              $15
#
#                     freeOrAudit review         subCat      broadCat  \
# 390                         NaN    NaN            NaN           NaN
# 392          Free Online Course      6    Visual Arts  Art & Design
# 393  Free Online Course (Audit)      2   Art & Design  Art & Design
# 394          Free Online Course      0    Visual Arts  Art & Design
# 395          Free Online Course      0    Visual Arts  Art & Design
# 391                         NaN    NaN            NaN           NaN
# 385                         NaN    NaN            NaN           NaN
# 386                         NaN    NaN            NaN           NaN
# 387                         NaN    NaN            NaN           NaN
# 388  Free Online Course (Audit)      1  Digital Media  Art & Design
#
#                          colaboratingUniv  freeAuditOrPaid
# 390                                   NaN              NaN
# 392                                                   free
# 393              The Museum of Modern Art            audit
# 394                                  NIOS             free
# 395                                  NIOS             free
# 391                                   NaN              NaN
# 385                                   NaN              NaN
# 386                                   NaN              NaN
# 387                                   NaN              NaN
# 388  The Pontificia Universidad Javeriana            audit
#
# [10 rows x 36 columns]

# %% [markdown]
# #### We can see for keyword "Acrylic Painting|painting", we have 2 courses for skill up that match 4 courses from course central from different providers.

# %% [markdown]
# ### Which are the most popular 10 courses from skill up that are in course central too?

# %%
top10 = matched.keyword.value_counts().head(10).reset_index().rename(columns={"index":"keyword", "keyword":"count"})
top10
# Out:
#                                              keyword  count
# 0  dog trainer|dog training|dog|dog walking|raw d...     21
# 1                                         Office 365     14
# 2                 digital marketing|digital marketer     13
# 3                              leadership|management     13
# 4                                     nutrition|diet     13
# 5                                           branding     12
# 6                                 project management     12
# 7                             depression|counselling     12
# 8                                        Negotiation     12
# 9                                 accounting|finance     12

# %% [markdown]
# ### How many courses does skill up have for those keywords?

# %%
def count_by_keyword(keyword):
    
    # Count no of skill up courses for the keyword
    skillup_count = matched[matched.keyword==keyword].query("courseProvider=='Skill Up'").shape[0]
    return pd.DataFrame({
        "keyword":keyword,
        "skillup_count":skillup_count
    }, index=[0])

# %%
# Apply the function to find no of courses for skill up for top 10 keywords
skilup_top10_count = pd.concat(list(map(count_by_keyword, top10.keyword))).reset_index(drop=True)

# Merge with the main data
final_df = pd.merge(top10, skilup_top10_count, on="keyword")

# Calculate competitors count
final_df["competitor_count"] = final_df["count"].sub(final_df.skillup_count)

# Rename column
final_df = final_df.rename(columns={"count":"total_count"})
final_df
# Out:
#                                              keyword  total_count  \
# 0  dog trainer|dog training|dog|dog walking|raw d...           21
# 1                                         Office 365           14
# 2                 digital marketing|digital marketer           13
# 3                              leadership|management           13
# 4                                     nutrition|diet           13
# 5                                           branding           12
# 6                                 project management           12
# 7                             depression|counselling           12
# 8                                        Negotiation           12
# 9                                 accounting|finance           12
#
#    skillup_count  competitor_count
# 0             13                 8
# 1              4                10
# 2              3                10
# 3              3                10
# 4              3                10
# 5              2                10
# 6              2                10
# 7              2                10
# 8              2                10
# 9              2                10

# %% [markdown]
# ### Takeaway: Out of 21 courses for keyword "dog trainer|dog training|dog|dog walking|raw diet|pet", 13 are from skill up and 8 are from the competitors. Out of 14 "Office 365" courses, 10 are from the competitors while 4 are from the skill up.
